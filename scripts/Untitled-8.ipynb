# %%
test_file = '/Users/noufi1/cursor new/STOCK_VERIFY_2-db-maped/backend/tests/api/test_websocket_api.py'

with open(test_file, 'r') as f:
    content = f.read()

new_test = """
def test_debug_settings():
    from backend.config import settings
    print(f"DEBUG: settings.JWT_SECRET = {settings.JWT_SECRET}")
    assert settings.JWT_SECRET == "test-jwt-secret-key-for-testing-only"
"""

with open(test_file, 'w') as f:
    f.write(content + new_test)
